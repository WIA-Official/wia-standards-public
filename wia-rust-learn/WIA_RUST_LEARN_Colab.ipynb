# %% [markdown]
# # 🦀 WIA-RUST-LEARN 영상 렌더링
#
# ## 📺 YouTube: [@yeonsamheum](https://www.youtube.com/@yeonsamheum)
#
# 이 노트북으로 28편의 Rust 강좌 영상을 렌더링합니다.
#
# ---
#
# ### 사용법
# 1. 각 셀을 순서대로 실행 (Shift + Enter)
# 2. 렌더링된 영상은 Google Drive에 저장됨
# 3. 다운로드 후 YouTube에 업로드!
#
# ---

# %% [markdown]
# ## 📦 Step 1: 설치 (처음 한 번만)

# %%
# Manim 설치 (약 2-3분 소요)
# !pip install manim -q
print("✅ Manim 설치 완료!")

# %%
# 한글 폰트 설치
# !apt-get install -y fonts-noto-cjk -qq
print("✅ 한글 폰트 설치 완료!")

# %%
# Google Drive 연결 (영상 저장용)
from google.colab import drive
drive.mount('/content/drive')
print("✅ Google Drive 연결 완료!")

# %% [markdown]
# ## 📥 Step 2: 코드 다운로드

# %%
# GitHub에서 코드 다운로드
# !git clone https://github.com/WIA-Official/wia-standards.git
# %cd wia-standards/wia-rust-learn/manim/episodes
print("✅ 코드 다운로드 완료!")
print("📁 현재 위치:", !pwd)

# %%
# 파일 목록 확인
# !ls -la *.py

# %% [markdown]
# ## 🎬 Step 3: 렌더링!
#
# ### 품질 옵션
# - `-ql` : 저화질 (테스트용, 빠름)
# - `-qm` : 중간 (720p)
# - `-qh` : 고화질 (1080p, YouTube 권장) ⭐
# - `-qk` : 4K (시간 오래 걸림)

# %% [markdown]
# ### 🧪 테스트: EP 0-01 저화질로 먼저 해보기

# %%
# 테스트 렌더링 (약 1분)
# !manim -ql level_0_setup.py EP_0_01_WhyRust
print("\n✅ 테스트 렌더링 완료!")

# %%
# 렌더링된 영상 확인
# !ls -la media/videos/level_0_setup/480p15/

# %%
# 영상 미리보기 (Colab에서 재생)
from IPython.display import Video
Video("media/videos/level_0_setup/480p15/EP_0_01_WhyRust.mp4")

# %% [markdown]
# ### 🎥 고화질 렌더링 (YouTube용)

# %%
# EP 0-01 고화질 렌더링 (약 5-10분)
# !manim -qh level_0_setup.py EP_0_01_WhyRust
print("\n✅ 고화질 렌더링 완료!")

# %% [markdown]
# ## 💾 Step 4: Google Drive에 저장

# %%
# Drive에 폴더 생성
# !mkdir -p "/content/drive/MyDrive/WIA-RUST-LEARN/videos"
print("✅ 폴더 생성 완료!")

# %%
# 렌더링된 영상을 Drive로 복사
# !cp media/videos/level_0_setup/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("✅ Google Drive에 저장 완료!")
print("📁 위치: Google Drive > WIA-RUST-LEARN > videos")

# %% [markdown]
# ---
#
# ## 📚 전체 에피소드 렌더링
#
# 아래에서 원하는 레벨/에피소드를 선택해서 실행하세요!

# %% [markdown]
# ### Level 0: 시작하기 (3편)

# %%
# Level 0 전체 렌더링 (약 15-20분)
# !manim -qh level_0_setup.py EP_0_01_WhyRust
# !manim -qh level_0_setup.py EP_0_02_Installing
# !manim -qh level_0_setup.py EP_0_03_CargoDeep

# Drive로 복사
# !cp media/videos/level_0_setup/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉 Level 0 완료!")

# %% [markdown]
# ### Level 1: 기초 (4편)

# %%
# Level 1 전체 렌더링
# !manim -qh level_1_basics.py EP_1_01_Variables
# !manim -qh level_1_basics.py EP_1_02_Functions
# !manim -qh level_1_basics.py EP_1_03_Strings
# !manim -qh level_1_basics.py EP_1_04_Collections

# !cp media/videos/level_1_basics/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉 Level 1 완료!")

# %% [markdown]
# ### ⭐ Level 2: 소유권 - NRT! (4편)

# %%
# Level 2 전체 렌더링 (가장 중요!)
# !manim -qh level_2_ownership.py EP_2_01_OwnershipRules
# !manim -qh level_2_ownership.py EP_2_02_MoveCopyClone
# !manim -qh level_2_ownership.py EP_2_03_Borrowing
# !manim -qh level_2_ownership.py EP_2_04_Lifetimes

# !cp media/videos/level_2_ownership/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉 Level 2 완료! (NRT 컨셉 포함)")

# %% [markdown]
# ### Level 3: 구조화 (3편)

# %%
# !manim -qh level_3_structure.py EP_3_01_StructsEnums
# !manim -qh level_3_structure.py EP_3_02_ErrorHandling
# !manim -qh level_3_structure.py EP_3_03_ModulesCrates

# !cp media/videos/level_3_structure/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉 Level 3 완료!")

# %% [markdown]
# ### Level 4: 고급 기능 (3편)

# %%
# !manim -qh level_4_advanced.py EP_4_01_GenericsTraits
# !manim -qh level_4_advanced.py EP_4_02_Closures
# !manim -qh level_4_advanced.py EP_4_03_SmartPointers

# !cp media/videos/level_4_advanced/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉 Level 4 완료!")

# %% [markdown]
# ### Level 5: 동시성 (2편)

# %%
# !manim -qh level_5_concurrency.py EP_5_01_ThreadsChannels
# !manim -qh level_5_concurrency.py EP_5_02_AsyncAwait

# !cp media/videos/level_5_concurrency/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉 Level 5 완료! (Core 인증 달성!)")

# %% [markdown]
# ### Level 6: 테스팅 & 도구 (2편)

# %%
# !manim -qh level_6_testing.py EP_6_01_Testing
# !manim -qh level_6_testing.py EP_6_02_CargoAdvanced

# !cp media/videos/level_6_testing/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉 Level 6 완료!")

# %% [markdown]
# ### Level 7: 고급 패턴 (2편)

# %%
# !manim -qh level_7_patterns.py EP_7_01_PatternDeep
# !manim -qh level_7_patterns.py EP_7_02_OOPRust

# !cp media/videos/level_7_patterns/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉 Level 7 완료!")

# %% [markdown]
# ### Level 8: Unsafe & 매크로 (2편)

# %%
# !manim -qh level_8_unsafe.py EP_8_01_UnsafeRust
# !manim -qh level_8_unsafe.py EP_8_02_Macros

# !cp media/videos/level_8_unsafe/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉 Level 8 완료! (Expert 인증 달성!)")

# %% [markdown]
# ### 👑 Level 9: 실전 프로젝트 (3편)

# %%
# !manim -qh level_9_projects.py EP_9_01_CLI
# !manim -qh level_9_projects.py EP_9_02_WebAPI
# !manim -qh level_9_projects.py EP_9_03_SystemTool

# !cp media/videos/level_9_projects/1080p60/*.mp4 "/content/drive/MyDrive/WIA-RUST-LEARN/videos/"
print("\n🎉🎉🎉 Level 9 완료! Master 인증 달성! 🎉🎉🎉")

# %% [markdown]
# ---
#
# ## ✅ 완료!
#
# ### 영상 위치
# **Google Drive > WIA-RUST-LEARN > videos**
#
# ### 다음 단계
# 1. Google Drive에서 .mp4 파일 다운로드
# 2. (선택) 음성/자막 추가
# 3. YouTube @yeonsamheum 채널에 업로드!
#
# ---
#
# **"Rust는 어렵지 않다. 다를 뿐이다."**
#
# 弘益人間 - 널리 인간을 이롭게 하라
#
# © 2025 SmileStory Inc. / WIA
